# %% [markdown]
# # RandomForest , Boosting
#  `-` [7]Machine learning

# %% [markdown]
# `-` 배깅의 문제
# - 배깅은 다양성이 적다. resampling 한다고 데이터의 트리가 다양화 될리가 없다.

# %% [markdown]
# # `-` 랜덤포레스트
# - 기존의 Max_feature 연구
#   - MaxFeature 의 의미는 임의로 feature 를 뽑아서 가장 중요한 변수를 제거하고 새로운 연구들을하여 생각해줄수있음.
# - 랜덤포레스트 = 배깅 + max_feature (라고 생각하면됨)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.tree
import sklearn.ensemble
#---#
import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_csv('https://raw.githubusercontent.com/guebin/MP2023/main/posts/insurance.csv')
df_train.head(2).T
# Out:
#                   0          1
# age              19         18
# sex          female       male
# bmi            27.9      33.77
# children          0          1
# smoker          yes         no
# region    southwest  southeast
# charges   16884.924  1725.5523

# %%
# Bagging 은 나무 저장
## forest 는 숲을 저장

# %%
# step1
X = pd.get_dummies(df_train.loc[:,'age':'region'],drop_first=True)
y = df_train['charges']
# step2 
predictr = sklearn.ensemble.BaggingRegressor()
# step3
predictr.fit(X,y)
# step4 -- pass
# Out:
# BaggingRegressor()

# %%
## Bagging 
trees = []
for i in range(100):
    tree = sklearn.tree.DecisionTreeRegressor() 
    X_sample,y_sample = boostrap(X,y) # 매순간 샘플바뀜
    tree.fit(X_sample,y_sample) # 일부 샘플만으로 적합
    trees.append(tree) # 학습한 나무를 저장
yhat = ensemble(trees) # 여러개의 나무를 종합하여 하나의 예측값을 만들어냄 (합주)

## RandomForeset 
forest = [] 
for i in range(100):
    tree = sklearn.tree.DecisionTreeRegressor(max_feature=1) # 매순간 설명변수 바뀜
    X_sample,y_sample = boostrap(X,y) # 매순간 샘플바뀜    
    tree.fit(X_sample,y_sample) # 일부설명변수, 일부샘플만으로 적합 
    forest.append(tree) # 학습한 나무를 숲에 저장 
yhat = ensemble(forest) # 여러개의 나무를 종합하여 하나의 예측값을 만들어냄 (합주)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 5
#       3 for i in range(100):
#       4     tree = sklearn.tree.DecisionTreeRegressor()
# ----> 5     X_sample,y_sample = boostrap(X,y) # 매순간 샘플바뀜
#       6     tree.fit(X_sample,y_sample) # 일부 샘플만으로 적합
#       7     trees.append(tree) # 학습한 나무를 저장
#
# Cell In[15], line 12, in boostrap(X, y, n_samples)
#       9 indices = np.random.choice(range(len(X)), size=n_samples, replace=True)
#      11 # 해당 인덱스를 사용하여 샘플 데이터셋을 생성합니다.
# ---> 12 X_sample = X[indices]
#      13 y_sample = y[indices]
#      15 return X_sample, y_sample
#
# File ~/anaconda3/envs/hf/lib/python3.10/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/envs/hf/lib/python3.10/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/envs/hf/lib/python3.10/site-packages/pandas/core/indexes/base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Int64Index([ 784,  740, 1213,  864,  977, 1335,  945, 1037,  575,  673,\n            ...\n             362,   97,  946,   85,   50,  691,  948,  562,  625, 1163],\n           dtype='int64', length=1338)] are in the [columns]"

# %%
# step1 -- pass 
# step2 
predictr = sklearn.ensemble.RandomForestRegressor(
    max_depth=1,
    max_features=1/3 #X column 의 퍼센트
)
# step3
predictr.fit(X,y)
# step4
# Out:
# RandomForestRegressor(max_depth=1, max_features=0.3333333333333333)

# %%
sklearn.tree.plot_tree(
    predictr.estimators_[1],
    feature_names=X.columns,
    max_depth=1
);

# %%
# RandomForest 재현

# %%
predictr.estimators_[0]
# Out:
# DecisionTreeRegressor(max_depth=1, max_features=0.3333333333333333,
#                       random_state=893252578)

# %%
predictr.estimators_[0].random_state
# Out:
# 893252578

# %%
rs = [tree.random_state for tree in predictr.estimators_]

# %%
# Forest 생성

# %%
my_forest = [sklearn.tree.DecisionTreeRegressor(max_depth=1,max_features=1/3,random_state=r) for r in rs]

# %%
my_forest[-1]
# Out:
# DecisionTreeRegressor(max_depth=1, max_features=0.3333333333333333,
#                       random_state=1515497481)

# %%
# 붓스트랩하기

# %%
sklearn.ensemble._forest._generate_sample_indices?
# Out:
# Signature:
# sklearn.ensemble._forest._generate_sample_indices(
#     random_state,
#     n_samples,
#     n_samples_bootstrap,
# )
# Docstring: Private function used to _parallel_build_trees function.
# File:      ~/anaconda3/envs/hf/lib/python3.10/site-packages/sklearn/ensemble/_forest.py
# Type:      function

# %%
sample = sklearn.ensemble._forest._generate_sample_indices

# %%
my_index = [sample(random_state=r,n_samples=1338,n_samples_bootstrap=1338) for r in rs]

# %%
for idx,tree in zip(my_index,my_forest):
    X_sampled, y_sampled = np.array(X)[idx], np.array(y)[idx]
    tree.fit(X_sampled,y_sampled)

# %%
def ensemble(forest):
    return np.stack([tree.predict(X) for tree in forest]).mean(axis=0)

# %%
sklearn.tree.plot_tree(my_forest[0])
# Out:
# [Text(0.5, 0.75, 'x[2] <= 1.5\nsquared_error = 141461528.619\nsamples = 1338\nvalue = 12976.233'),
#  Text(0.25, 0.25, 'squared_error = 133403225.02\nsamples = 899\nvalue = 12259.787'),
#  Text(0.75, 0.25, 'squared_error = 154759901.601\nsamples = 439\nvalue = 14443.396')]

# %%
sklearn.tree.plot_tree(predictr.estimators_[0])
# Out:
# [Text(0.5, 0.75, 'x[2] <= 1.5\nsquared_error = 141461528.619\nsamples = 845\nvalue = 12976.233'),
#  Text(0.25, 0.25, 'squared_error = 133403225.02\nsamples = 573\nvalue = 12259.787'),
#  Text(0.75, 0.25, 'squared_error = 154759901.601\nsamples = 272\nvalue = 14443.396')]
